# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('RL Journalism Data Request - May 2023.xlsx')
df.head()
# Out:
#    bankruptcyInLast3Years  bankruptcyTotal  Fico09 Employmentstatus  \
# 0                       0                0     607         Employed
# 1                       0                0     722         Employed
# 2                       0                0     657         Employed
# 3                       0                0     772         Employed
# 4                       0                0     833          Retired
#
#    Selectedamount  realEstateMonthlyPayment  unsecuredTradelineBalanceAmount  \
# 0           10000                      1529                                0
# 1           20000                      2668                                0
# 2            3433                         0                             4567
# 3           15000                       478                                0
# 4           17000                       715                                0
#
#    revolvingCreditAvailable  revolvingCreditAmount  \
# ...

# %%
df.tail()
# Out:
#        bankruptcyInLast3Years  bankruptcyTotal  Fico09 Employmentstatus  \
# 32587                       0                0     702         Employed
# 32588                       0                0     687         Employed
# 32589                       0                0     801          Retired
# 32590                       0                0     697         Employed
# 32591                       0                0     694         Employed
#
#        Selectedamount  realEstateMonthlyPayment  \
# 32587           16000                       672
# 32588           11500                      1759
# 32589           10000                         0
# 32590           13000                         0
# 32591           20000                      3124
#
#        unsecuredTradelineBalanceAmount  revolvingCreditAvailable  \
# 32587                                0                      5531
# 32588                              530                        13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32592 entries, 0 to 32591
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   bankruptcyInLast3Years           32592 non-null  int64
#  1   bankruptcyTotal                  32592 non-null  int64
#  2   Fico09                           32592 non-null  int64
#  3   Employmentstatus                 32569 non-null  object
#  4   Selectedamount                   32592 non-null  int64
#  5   realEstateMonthlyPayment         32592 non-null  int64
#  6   unsecuredTradelineBalanceAmount  32592 non-null  int64
#  7   revolvingCreditAvailable         32592 non-null  int64
#  8   revolvingCreditAmount            32592 non-null  int64
#  9   revolvingTradelinesBalance       32592 non-null  int64
#  10  otherMonthlyPayment              32592 non-null  int64
#  11  otherTradelinesBalance           32592 non-null  int64
# ...

# %%
df['State']
# Out:
# 0        TX
# 1        OK
# 2        AL
# 3        MO
# 4        IL
#          ..
# 32587    WI
# 32588    SC
# 32589    TN
# 32590    LA
# 32591    NE
# Name: State, Length: 32592, dtype: object

# %%
sns.boxplot(data=df, x='Age', y='dti')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='dti'>
